# %% [markdown]
# # AgentOS Health Check

# %%
import requests
BASE = 'http://localhost:8080'
requests.get(f'{BASE}/health', timeout=20).json()

# %%
requests.get(f'{BASE}/routes', timeout=20).json()
