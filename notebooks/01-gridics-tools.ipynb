# %% [markdown]
# # Gridics Routes Smoke Tests

# %%
import requests
BASE = 'http://localhost:8080'

# %%
requests.get(f'{BASE}/api/gridics/markets', timeout=30).json()

# %%
params = {'state_env': 'fl', 'address': '444 BRICKELL AVE', 'zipCode': '33131'}
requests.get(f'{BASE}/api/gridics/property-record', params=params, timeout=30).json()
