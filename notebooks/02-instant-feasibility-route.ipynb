# %% [markdown]
# # Instant Feasibility Route Test

# %%
import json
from pathlib import Path
import requests
BASE = 'http://localhost:8080'

# %%
payload = json.loads(Path('../cookbook/01-instant-feasibility-api/fixtures/request.json').read_text())
resp = requests.post(f'{BASE}/api/instant-feasibility', json=payload, timeout=45)
resp.status_code, resp.json()
